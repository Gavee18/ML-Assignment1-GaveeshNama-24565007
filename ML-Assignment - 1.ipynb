# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Gaveesh\\Documents\\MTECH AI 1st sem\\Machine Learning\\Assignment 1\\Big_Black_Money_Dataset.csv")

# %%
# number of null values in dataset

df.isnull().sum()
# Out:
# Transaction ID                 0
# Country                        0
# Amount (USD)                   0
# Transaction Type               0
# Date of Transaction            0
# Person Involved                0
# Industry                       0
# Destination Country            0
# Reported by Authority          0
# Source of Money                0
# Money Laundering Risk Score    0
# Shell Companies Involved       0
# Financial Institution          0
# Tax Haven Country              0
# dtype: int64

# %%
df
# Out:
#      Transaction ID       Country  Amount (USD)   Transaction Type  \
# 0      TX0000000001        Brazil  3.267530e+06  Offshore Transfer
# 1      TX0000000002         China  4.965767e+06    Stocks Transfer
# 2      TX0000000003            UK  9.416750e+04    Stocks Transfer
# 3      TX0000000004           UAE  3.864201e+05    Cash Withdrawal
# 4      TX0000000005  South Africa  6.433784e+05     Cryptocurrency
# ...             ...           ...           ...                ...
# 9995   TX0000009996     Singapore  2.209229e+06  Offshore Transfer
# 9996   TX0000009997           UAE  4.800338e+06  Property Purchase
# 9997   TX0000009998            UK  4.891953e+05    Stocks Transfer
# 9998   TX0000009999        Brazil  2.233581e+06  Offshore Transfer
# 9999   TX0000010000   Switzerland  3.846778e+05    Stocks Transfer
#
#       Date of Transaction Person Involved      Industry Destination Country  \
# 0     2013-01-01 00:00:00     Person_1101  Construction                 USA
# ...

# %%
# Univarient Analysis

# Country vice number of transactions

df['Country'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Number of different type of transactions

df['Transaction Type'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Which industry have most transactions

df['Industry'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Pie chart of number of Transactions reported to authorities

df['Reported by Authority'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Reported by Authority'>

# %%
# Month vice distribution of number of Transactions

df['Date of Transaction'] = pd.to_datetime(df['Date of Transaction'])
df['month'] = df['Date of Transaction'].dt.month_name()


df['month'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Bivarient analysis

import matplotlib.pyplot as plt
import seaborn as sns

# How much money transfered in which month (Numerical - Catagorical)

plt.figure(figsize=(20,6))
sns.barplot(x=df['month'], y=df['Amount (USD)'])
plt.title('Transaction Amount vs. Date')
plt.show()

# %%
# how much money in which Industry (Numerical - Catagorical)

plt.figure(figsize=(12,6))
sns.barplot(x=df['Industry'], y=df['Amount (USD)'])
plt.title('Scatter Plot: Amount (USD) vs. Industry')
plt.show()

# %%
# Transaction amount accross countries (Numerical - Catagorical)

plt.figure(figsize=(15,6))
sns.boxplot(x='Country', y='Amount (USD)', data=df)
plt.xticks(rotation=90)
plt.title('Transaction Amount across Countries')
plt.show()

# %%
# Heatmap of cases reported by authorities and sources of money (Catagorical - Catagorical)

heatmap_data = pd.crosstab(df['Reported by Authority'], df['Source of Money'])
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, fmt="d", cmap="YlGnBu")
plt.title('Heatmap of Cases Reported by Authority and Source of Money')
plt.xlabel('Source of Money')
plt.ylabel('Reported by Authority')
plt.show()
